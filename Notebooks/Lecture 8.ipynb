# %% [markdown]
# ## Name : Manas Ohara
# ## Div : A
# ## Roll no- 452

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
subjectlabel = ["English", "Maths", "Science", "Hindi"]
plt.pie(y, labels = subjectlabel)
plt.legend(title="Subject %")
plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np


y = np.array([50,50])

subjectlabel = ["Girls", "Boys",]


plt.pie(y, labels = subjectlabel)

plt.legend(title="Gender%")

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np


y = np.array([40,20,40])

subjectlabel = ["Walk", "Cycle", "Car/Bus",]


plt.pie(y, labels = subjectlabel)

plt.legend(title="Subject %")

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np


y = np.array([85,15])

subjectlabel = ["Love Maths","Hate Maths"]


plt.pie(y, labels = subjectlabel)

plt.legend(title="Subject %")

plt.show()
