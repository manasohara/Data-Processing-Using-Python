# %% [markdown]
# ## date and period timstamp

# %%
import pandas as pd
pd.date_range('2015-07-03 11:00', periods=8, freq='H')
# Out:
# DatetimeIndex(['2015-07-03 11:00:00', '2015-07-03 12:00:00',
#                '2015-07-03 13:00:00', '2015-07-03 14:00:00',
#                '2015-07-03 15:00:00', '2015-07-03 16:00:00',
#                '2015-07-03 17:00:00', '2015-07-03 18:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %% [markdown]
# ## reading csv file and head tail in it

# %%
df=pd.read_csv("germanydaily.csv")
df=df.set_index('Date')
df.tail(4)
df.head(4)
# Out:
#             Consumption     Wind   Solar  WindSolar  Year  Month   Weekday
# Date
# 2012-02-01     1511.866  199.607  43.502    243.109  2012      2  Wednesday
# 2012-02-02     1563.407   73.469  44.675    118.144  2012      2   Thursday
# 2012-02-03     1563.631   36.352  46.510     82.862  2012      2     Friday
# 2012-02-04     1372.614   20.551  45.225     65.776  2012      2   Saturday

# %% [markdown]
# ## heatmap and seaborn
# ## cmap colors=Blues
#
# ´Greens
#
# ´PiYG
#
# ´Summer
#
# ´winter

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Create a dataset
df = pd.DataFrame(np.random.random((10,10)), columns=["a","b","c","d","e","f","g","h","i","j"])
# plot using a color palette
sns.heatmap(df, cmap="winter")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Create a dataset
df = pd.DataFrame(np.random.random((10,10)), columns=["a","b","c","d","e","f","g","h","i","j"])
# plot using a color palette
sns.heatmap(df, cmap="summer",annot=True,annot_kws={"size":6})
##annot is for displaying no. onthat heatmap and kws is keyword size
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
sns.set()
flights=sns.load_dataset("flights")
flights=flights.pivot("month","year","passengers")
#pivot-charrt
ax=sns.heatmap(flights,cmap='copper')
plt.title("Heatmap flight data")
plt.show()
print(flights)
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...
